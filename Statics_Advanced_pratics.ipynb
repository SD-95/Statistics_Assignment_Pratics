# %% [markdown]
# ## Q1. Generate a list of 100 integers containing values between 90 to 130 and store it in the variable `int_list`.
# ### After generating the list, find the following:
# ### (i) Write a Python function to calculate the mean of a given list of numbers. Create a function to find the median of a list of numbers.
# ### (ii) Develop a program to compute the mode of a list of integers.
# ### (iii) Implement a function to calculate the weighted mean of a list of values and their corresponding weights.
# ### (iv) Write a Python function to find the geometric mean of a list of positive numbers.
# ### (v) Create a program to calculate the harmonic mean of a list of values.
# ### (vi) Build a function to determine the midrange of a list of numbers (average of the minimum and maximum).
# ### (vii) Implement a Python program to find the trimmed mean of a list, excluding a certain percentage of outliers

# %%
import random

# Generate a list of 100 integers between 90 and 130
int_list = [random.randint(90, 130) for _ in range(100)]

# (i) Mean and Median Functions
def mean(lst):
    return sum(lst) / len(lst)

print("Mean:", mean(int_list))

def median(lst):
    sorted_lst = sorted(lst)
    n = len(sorted_lst)
    if n % 2 == 0:
        return (sorted_lst[n//2 - 1] + sorted_lst[n//2]) / 2
    else:
        return sorted_lst[n//2]
    
print("Median:", median(int_list))

# (ii) Mode Function
def mode(lst):
    counts = {}
    for num in lst:
        counts[num] = counts.get(num, 0) + 1
    max_count = max(counts.values())
    return [num for num, count in counts.items() if count == max_count]

print("Mode:", mode(int_list))

# (iii) Weighted Mean Function
def weighted_mean(values, weights):
    weighted_sum = sum(value * weight for value, weight in zip(values, weights))
    total_weight = sum(weights)
    return weighted_sum / total_weight


values = int_list
weights = [2, 3, 1]
weighted_avg = weighted_mean(values, weights)
print("Weighted mean:", weighted_avg)

# (iv) Geometric Mean Function
def geometric_mean(lst):
    product = 1
    for num in lst:
        product *= num
    return product ** (1/len(lst))

print("geometric_mean:", geometric_mean(int_list))

# (v) Harmonic Mean Function
def harmonic_mean(lst):
    harmonic_sum = sum(1/num for num in lst)
    return len(lst) / harmonic_sum

print("harmonic_mean:", harmonic_mean(int_list))

# (vi) Midrange Function
def midrange(lst):
    return (min(lst) + max(lst)) / 2

print("midrange:", midrange(int_list))

# (vii) Trimmed Mean Function
def trimmed_mean(lst, trim_percent):
    n = len(lst)
    trim_index = int(n * trim_percent / 100)
    sorted_lst = sorted(lst)
    trimmed_lst = sorted_lst[trim_index:-trim_index]
    return mean(trimmed_lst)

int_list = int_list
trim_percentage = 10 
trimmed_mean_value = trimmed_mean(int_list, trim_percentage)
print("Trimmed mean:", trimmed_mean_value)
# Out:
# Mean: 111.11
# Median: 112.0
# Mode: [112]
# Weighted mean: 106.83333333333333
# geometric_mean: 110.58030114703894
# harmonic_mean: 110.04211120393543
# midrange: 110.0
# Trimmed mean: 111.3625

# %% [markdown]
# ## Q2. Generate a list of 500 integers containing values between 200 to 300 and store it in the variable `int_list2`.
# ### After generating the list, find the following:
#
# ### (i) Compare the given list of visualization for the given data:
#     ### 1. Frequency & Gaussian distribution
#     ### 2. Frequency smoothened KDE plot
#     ### 3. Gaussian distribution & smoothened KDE plot
# ### (ii) Write a Python function to calculate the range of a given list of numbers.
# ### (iii) Create a program to find the variance and standard deviation of a list of numbers.
# ### (iv) Implement a function to compute the interquartile range (IQR) of a list of values.
# ### (v) Build a program to calculate the coefficient of variation for a dataset.
# ### (vi) Write a Python function to find the mean absolute deviation (MAD) of a list of numbers.
# ### (vii) Create a program to calculate the quartile deviation of a list of values.
# ### (viii) Implement a function to find the range-based coefficient of dispersion for a dataset.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate a list of 500 integers between 200 and 300
int_list2 = [random.randint(200, 300) for _ in range(500)]

# (i) Visualizations
plt.figure(figsize=(12, 6))

# 1. Frequency & Gaussian distribution
plt.subplot(2, 2, 1)
sns.histplot(int_list2, kde=True)
plt.title("Frequency & Gaussian Distribution")

# 2. Frequency smoothened KDE plot
plt.subplot(2, 2, 2)
sns.histplot(int_list2, kde=True, stat="density", kde_kws={'bw_adjust': 2})
plt.title("Frequency Smoothened KDE Plot")

# 3. Gaussian distribution & smoothened KDE plot
plt.subplot(2, 2, 3)
sns.kdeplot(int_list2, shade=True)
plt.title("Gaussian Distribution & Smoothened KDE Plot")

plt.tight_layout()
plt.show()

# (ii) Range Function
def range_of_list(lst):
    return max(lst) - min(lst)

print("Range:", range_of_list(int_list2))

# (iii) Variance and Standard Deviation
def variance_std_dev(lst):
    mean = sum(lst) / len(lst)
    variance = sum((x - mean)**2 for x in lst) / len(lst)
    std_dev = variance**0.5
    return variance, std_dev

print("Variance, Standard Deviation:", variance_std_dev(int_list2))

# (iv) Interquartile Range (IQR)
def iqr(lst):
    q1 = np.quantile(lst, 0.25)
    q3 = np.quantile(lst, 0.75)
    return q3 - q1

print("Interquartile Range:", iqr(int_list2))

# (v) Coefficient of Variation
def coefficient_of_variation(lst):
    std_dev = np.std(lst)
    mean = np.mean(lst)
    return (std_dev / mean) * 100

print("Coefficient of Variation:", coefficient_of_variation(int_list2))

# (vi) Mean Absolute Deviation (MAD)
def mad(lst):
    mean = np.mean(lst)
    return np.mean(np.abs(lst - mean))

print("Mean Absolute Deviation:", mad(int_list2))

# (vii) Quartile Deviation
def quartile_deviation(lst):
    q1 = np.quantile(lst, 0.25)
    q3 = np.quantile(lst, 0.75)
    return (q3 - q1) / 2

print("Quartile Deviation:", quartile_deviation(int_list2))

# (viii) Range-Based Coefficient of Dispersion
def range_based_coefficient_of_dispersion(lst):
    return (max(lst) - min(lst)) / (max(lst) + min(lst))

print("Range-Based Coefficient of Dispersion:", range_based_coefficient_of_dispersion(int_list2))
# Out:
# C:\Users\SD_04\AppData\Local\Temp\ipykernel_3932\3979324576.py:24: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(int_list2, shade=True)
# Range: 100
# Variance, Standard Deviation: (811.5231040000001, 28.487244584199438)
# Interquartile Range: 47.0
# Coefficient of Variation: 11.425243279831006
# Mean Absolute Deviation: 24.613343999999998
# Quartile Deviation: 23.5
# Range-Based Coefficient of Dispersion: 0.2

# %% [markdown]
# ## Q3  Write a Python class representing a discrete random variable with methods to calculate its expected value and variance.

# %%
class DiscreteRandomVariable:
    def __init__(self, pmf):
        self.pmf = pmf

    def expected_value(self):
        expected_value = 0
        for value, probability in self.pmf.items():
            expected_value += value * probability
        return expected_value

    def variance(self):
        mean = self.expected_value()
        variance = 0
        for value, probability in self.pmf.items():
            variance += probability * (value - mean)**2
        return variance
    
pmf = {1: 0.2, 2: 0.3, 3: 0.5}
rv = DiscreteRandomVariable(pmf)

print("Expected value:", rv.expected_value())
print("Variance:", rv.variance())
# Out:
# Expected value: 2.3
# Variance: 0.61

# %% [markdown]
# ## Q4. Implement a program to simulate the rolling o6 a 6air six-sided die and calculate the expected value and variance o6 the outcomes.

# %%
import random

def simulate_dice_roll(num_rolls):
    rolls = []
    for _ in range(num_rolls):
        roll = random.randint(1, 6)
        rolls.append(roll)
    return rolls

def calculate_expected_value(rolls):
    return sum(rolls) / len(rolls)

def calculate_variance(rolls):
    mean = calculate_expected_value(rolls)
    variance = sum((roll - mean)**2 for roll in rolls) / len(rolls)
    return variance

if __name__ == "__main__":
    num_rolls = 10000  # Adjust the number of rolls as needed
    rolls = simulate_dice_roll(num_rolls)

    expected_value = calculate_expected_value(rolls)
    variance = calculate_variance(rolls)

    print("Expected value:", expected_value)
    print("Variance:", variance)
# Out:
# Expected value: 3.5248
# Variance: 2.96358496

# %% [markdown]
# ## Q5. Create a Python function to generate random samples 6rom a given probability distribution (e.g., binomial, Poisson) and calculate their mean and variance.

# %%
import numpy as np

def generate_random_samples(distribution, **kwargs):
    if distribution == 'binomial':
        n = kwargs.get('n', 10)
        p = kwargs.get('p', 0.5)
        return np.random.binomial(n, p, size=1000)
    elif distribution == 'poisson':
        lam = kwargs.get('lam', 5)
        return np.random.poisson(lam, size=1000)
    else:
        raise ValueError("Invalid distribution")

def calculate_mean_and_variance(samples):
    mean = np.mean(samples)
    variance = np.var(samples)
    return mean, variance

binomial_samples = generate_random_samples('binomial', n=10, p=0.3)
poisson_samples = generate_random_samples('poisson', lam=5)

binomial_mean, binomial_variance = calculate_mean_and_variance(binomial_samples)
poisson_mean, poisson_variance = calculate_mean_and_variance(poisson_samples)

print("Binomial distribution:")
print("Mean:", binomial_mean)
print("Variance:", binomial_variance)

print("\nPoisson distribution:")
print("Mean:", poisson_mean)
print("Variance:", poisson_variance)
# Out:
# Binomial distribution:
# Mean: 2.921
# Variance: 2.134759
#
# Poisson distribution:
# Mean: 5.026
# Variance: 4.871324

# %% [markdown]
# ## Q6 Write a Python script to generate random numbers from a Gaussian (normal) distribution and compute the mean, variance, and standard deviation o6 the samples

# %%
import numpy as np

def generate_gaussian_samples(mean, std_dev, num_samples):
    samples = np.random.normal(mean, std_dev, num_samples)
    return samples

def calculate_statistics(samples):
    mean = np.mean(samples)
    variance = np.var(samples)
    std_dev = np.std(samples)
    return mean, variance, std_dev

mean = 10
std_dev = 2
num_samples = 1000

gaussian_samples = generate_gaussian_samples(mean, std_dev, num_samples)
sample_mean, sample_variance, sample_std_dev = calculate_statistics(gaussian_samples)

print("Mean:", sample_mean)
print("Variance:", sample_variance)
print("Standard Deviation:", sample_std_dev)
# Out:
# Mean: 9.93776881559534
# Variance: 3.926963634977647
# Standard Deviation: 1.9816567904098952

# %% [markdown]
# ## Q7. Use seaborn library to load tips dataset. Find the 6ollowing 6rom the dataset 6or the columns total_bill and tip`:
# ### (i) Write a Python function that calculates their skewness.
# ### (ii) Create a program that determines whether the columns exhibit positive skewness, negative skewness, or is approximately symmetric.
# ### (iii) Write a function that calculates the covariance between two columns.
# ### (iv) Implement a Python program that calculates the Pearson correlation coefficient between two columns.
# ### (v) Write a script to visualize the correlation between two specific columns in a Pandas DataFrame using scatter plots.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")


# (i) Skewness Function
def calculate_skewness(data):
    skewness = data.skew()
    return skewness


skewness_tip = calculate_skewness(tips["tip"])
print("Skewness of tip:", skewness_tip)


# (ii) Skewness Analysis
def analyze_skewness(data):
    skewness = calculate_skewness(data)
    if skewness > 0:
        return "Positive Skewness"
    elif skewness < 0:
        return "Negative Skewness"
    else:
        return "Approximately Symmetric"


total_bill_skewness = analyze_skewness(tips["total_bill"])
tip_skewness = analyze_skewness(tips["tip"])

print("Total Bill Skewness:", total_bill_skewness)
print("Tip Skewness:", tip_skewness)


# (iii) Covariance Function
def calculate_covariance(x, y):
    covariance = x.cov(y)
    return covariance

covariance = calculate_covariance(tips["total_bill"], tips["tip"])
print("Covariance:", covariance)


# (iv) Pearson Correlation Coefficient
def calculate_pearson_correlation(x, y):
    correlation = x.corr(y)
    return correlation


correlation = calculate_pearson_correlation(tips["total_bill"], tips["tip"])
print("Pearson Correlation Coefficient:", correlation)


# (v) Visualize Correlation
def visualize_correlation(x, y, xlabel, ylabel):
    plt.scatter(x, y)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(f"Correlation between {xlabel} and {ylabel}")
    plt.show()


visualize_correlation(tips["total_bill"], tips["tip"], "Total Bill", "Tip")
# Out:
# Skewness of tip: 1.4654510370979401
# Total Bill Skewness: Positive Skewness
# Tip Skewness: Positive Skewness
# Covariance: 8.323501629224854
# Pearson Correlation Coefficient: 0.6757341092113645

# %% [markdown]
# ## Q8. Write a Python function to calculate the probability density function (PDF) of a continuous random variable for a given normal distribution

# %%
import scipy.stats as stats

def calculate_pdf(x, mu, sigma):
    pdf_value = stats.norm.pdf(x, loc=mu, scale=sigma)
    return pdf_value

x_value = 2.5
mean = 1.5
std_dev = 0.5

pdf = calculate_pdf(x_value, mean, std_dev)
print("The PDF value at x =", x_value, "is:", pdf)
# Out:
# The PDF value at x = 2.5 is: 0.10798193302637613

# %% [markdown]
# ## Q9. Create a program to calculate the cumulative distribution function (CDF) of exponential distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

def exponential_cdf(x, lamda):
  return 1 - np.exp(-lamda * x)


lamda = 2  # Rate parameter
x_values = np.linspace(0, 5, 100)  # Range of x values
cdf_values = exponential_cdf(x_values, lamda)


plt.plot(x_values, cdf_values)
plt.xlabel('x')
plt.ylabel('CDF')
plt.title('Exponential CDF')
plt.grid()
plt.show()

# %% [markdown]
# ## Q10 Write a Python function to calculate the probability mass function (PMF) of Poisson distribution.

# %%
import numpy as np
import scipy.stats as stats

def poisson_pmf(k, lamda):
  pmf_value = stats.poisson.pmf(k, lamda)
  return pmf_value


lamda = 3  # Rate parameter
k_values = np.arange(0, 10)  # Range of k values
pmf_values = poisson_pmf(k_values, lamda)

for k, pmf in zip(k_values, pmf_values):
  print(f"{k}\t{pmf:.4f}")
# Out:
# 0	0.0498
# 1	0.1494
# 2	0.2240
# 3	0.2240
# 4	0.1680
# 5	0.1008
# 6	0.0504
# 7	0.0216
# 8	0.0081
# 9	0.0027

# %% [markdown]
# ## Q11 A company wants to test if a new website layout leads to a higher conversion rate (percentage of visitors who make a purchase). They collect data from the old and new layouts to compare.
# ### To generate the data use the following command:
#
# ### python code
#
# ### import numpy as np
# ### 50 purchases out of 1000 visitors
# ### old_layout = np.array([1] * 50 + [0] * 950)
# ### 70 purchases out of 1000 visitors
# ### new_layout = np.array([1] * 70 + [0] * 930)
# ### Apply z-test to find which layout is successful.

# %%
import numpy as np
from scipy.stats import norm

# Given data
old_layout = np.array([1] * 50 + [0] * 950)
new_layout = np.array([1] * 70 + [0] * 930)

# Calculate conversion rates and sample sizes
old_conversion_rate = np.mean(old_layout)
new_conversion_rate = np.mean(new_layout)
n1 = len(old_layout)
n2 = len(new_layout)

# Calculate pooled standard error
pooled_se = np.sqrt(((old_conversion_rate * (1 - old_conversion_rate)) / n1) + ((new_conversion_rate * (1 - new_conversion_rate)) / n2))

# Calculate the z-score
z_score = (new_conversion_rate - old_conversion_rate) / pooled_se

# Set the significance level (alpha)
alpha = 0.05

# Calculate the critical value
critical_value = norm.ppf(1 - alpha/2)

# Print the results
print("Z-score:", z_score)
print("Critical value:", critical_value)

# Compare the z-score with the critical value
if abs(z_score) > critical_value:
    print("Reject the null hypothesis. The new layout has a significantly higher conversion rate.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in conversion rates.")
# Out:
# Z-score: 1.8847805889708436
# Critical value: 1.959963984540054
# Fail to reject the null hypothesis. There is no significant difference in conversion rates.

# %% [markdown]
# ## Q12 A tutoring service claims that its program improves students' exam scores. A sample of students who participated in the program was taken, and their scores before and after the program were recorded.
#
# ## Use the below code to generate samples of respective arrays of marks:
#
# ### python code
#
# ### before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
# ### after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])
#
# ### Use z-test to find if the claims made by tutor are true or false.

# %%
import numpy as np
from scipy.stats import ttest_rel

# Sample data
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

# Perform paired t-test
t_stat, p_value = ttest_rel(after_program, before_program)

# Set significance level (alpha)
alpha = 0.05

# Print the results
print("t-statistic:", t_stat)
print("p-value:", p_value)

# Compare p-value with alpha
if p_value < alpha:
    print("Reject the null hypothesis. The tutoring program is effective in improving scores.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in scores.")
# Out:
# t-statistic: 4.593190894944668
# p-value: 0.0013030932910086035
# Reject the null hypothesis. The tutoring program is effective in improving scores.

# %% [markdown]
# ## Q13. A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They conduct a study and record blood pressure measurements before and after administering the drug.
#
# ### Use the below code to generate samples of respective arrays of blood pressure:
#
# ### python_code
#
# ### before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
#
# ### after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])
#
# ### Implement z-test to find if the drug really works or not.

# %%
import numpy as np
from scipy.stats import ttest_rel

# Sample data
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])

# Perform paired t-test
t_stat, p_value = ttest_rel(after_drug, before_drug)

# Set significance level (alpha)
alpha = 0.05

# Print the results
print("t-statistic:", t_stat)
print("p-value:", p_value)

# Compare p-value with alpha
if p_value < alpha:
    print("Reject the null hypothesis. The drug is effective in reducing blood pressure.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in blood pressure.")
# Out:
# t-statistic: -10.04987562112089
# p-value: 3.433031432681152e-06
# Reject the null hypothesis. The drug is effective in reducing blood pressure.

# %% [markdown]
# # Q14 A customer service department claims that their average response time is less than 5 minutes. A sample of recent custo:er interactions was taken, and the response times were recorded.
#
#
# ### Implement the below code to generate the array of response time:
#
# ### response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])
#
# ### Implement z-test to find the claims made by customer service department are true or false.

# %%
import numpy as np
from scipy.stats import ttest_1samp

# Sample data
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])

# Set the hypothesized mean
hypothesized_mean = 5

# Perform one-sample t-test
t_stat, p_value = ttest_1samp(response_times, hypothesized_mean)

# Set significance level (alpha)
alpha = 0.05

# Print the results
print("t-statistic:", t_stat)
print("p-value:", p_value)

# Compare p-value with alpha
if p_value < alpha:
    print("Reject the null hypothesis. The average response time is less than 5 minutes.")
else:
    print("Fail to reject the null hypothesis. There is no significant evidence that the average response time is less than 5 minutes.")
# Out:
# t-statistic: -3.1844572260429627
# p-value: 0.011104982316785018
# Reject the null hypothesis. The average response time is less than 5 minutes.

# %% [markdown]
# # Q15 A company is testing two different website layouts to see which one leads to higher click-through rates. Write a Python function to perform an A/B test analysis, including calculating the t-statistic, degrees of freedom, and p-value.
#
#
# ### Use the following data:
#
# ### layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
#
# ### layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

# %%
import numpy as np
from scipy.stats import ttest_ind

def ab_test(layout_a, layout_b):
  t_stat, p_value = ttest_ind(layout_a, layout_b)
  df = len(layout_a) + len(layout_b) - 2

  return t_stat, df, p_value

layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

t_stat, df, p_value = ab_test(layout_a_clicks, layout_b_clicks)

print("t-statistic:", t_stat)
print("Degrees of freedom:", df)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
  print("Reject the null hypothesis. Layout B has significantly higher click-through rates.")
else:
  print("Fail to reject the null hypothesis. There is no significant difference in click-through rates.")
# Out:
# t-statistic: -7.298102156175071
# Degrees of freedom: 18
# p-value: 8.833437608301987e-07
# Reject the null hypothesis. Layout B has significantly higher click-through rates.

# %% [markdown]
# # Q16 A pharmaceutical company wants to determine if a new drug is more effective than an existing drug in reducing cholesterol levels. Create a program to analyze the clinical trial data and calculate the t-statistic and p-value for the treatment effect.
#
#
# ### Use the followi3g data of cholestrol level:
#
# ### existi3g_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
#
# ### 3ew_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

# %%
import numpy as np
from scipy.stats import ttest_ind

def compare_drug_effectiveness(drug_a, drug_b):
  t_stat, p_value = ttest_ind(drug_a, drug_b)
  df = len(drug_a) + len(drug_b) - 2

  return t_stat, df, p_value

existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

t_stat, df, p_value = compare_drug_effectiveness(existing_drug_levels, new_drug_levels)

print("t-statistic:", t_stat)
print("Degrees of freedom:", df)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
  print("Reject the null hypothesis. The new drug is more effective in reducing cholesterol levels.")
else:
  print("Fail to reject the null hypothesis. There is no significant difference in the effectiveness of the two drugs.")
# Out:
# t-statistic: 4.14048098620866
# Degrees of freedom: 18
# p-value: 0.0006143398442372505
# Reject the null hypothesis. The new drug is more effective in reducing cholesterol levels.

# %% [markdown]
# # Q17 A school district introduces an educational intervention program to improve math scores. Write a Python function to analyze pre- and post-intervention test scores, calculating the t-statistic and p-value to determine if the intervention had a significant impact.
#
# ### Use the followi3g data of test score:
#
#   ### pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
#
#   ### post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

# %%
import numpy as np
from scipy.stats import ttest_rel

def analyze_intervention_impact(pre_scores, post_scores):
  t_stat, p_value = ttest_rel(post_scores, pre_scores)
  df = len(pre_scores) - 1

  return t_stat, df, p_value

pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

t_stat, df, p_value = analyze_intervention_impact(pre_intervention_scores, post_intervention_scores)

print("t-statistic:", t_stat)
print("Degrees of freedom:", df)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
  print("Reject the null hypothesis. The intervention had a significant positive impact on math scores.")
else:
  print("Fail to reject the null hypothesis. There is no significant evidence of an impact from the intervention.")
# Out:
# t-statistic: 4.42840883965761
# Degrees of freedom: 9
# p-value: 0.0016509548165795493
# Reject the null hypothesis. The intervention had a significant positive impact on math scores.

# %% [markdown]
# # Q18 An HR department wants to investigate if there's a gender-based salary gap within the company. Develop a program to analyze salary data, calculate the t-statistic, and determine if there's a statistically significant difference between the average salaries of male and female employees.
#
# ### Use the below code to generate synthetic dataY
#
# # Generate synthetic salary data for male and female employees
#
# ### np.random.seed(0)  # For reproducibility
#
# ### male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
#
# ### female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

# %%
import numpy as np
from scipy.stats import ttest_ind

def analyze_salary_gap(male_salaries, female_salaries):
  t_stat, p_value = ttest_ind(male_salaries, female_salaries)
  df = len(male_salaries) + len(female_salaries) - 2

  return t_stat, df, p_value

# Generate synthetic salary data
np.random.seed(0)
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

t_stat, df, p_value = analyze_salary_gap(male_salaries, female_salaries)

print("t-statistic:", t_stat)
print("Degrees of freedom:", df)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
  print("Reject the null hypothesis. There is a significant difference in average salaries between genders.")
else:
  print("Fail to reject the null hypothesis. There is no significant evidence of a salary gap.")
# Out:
# t-statistic: 0.06114208969631383
# Degrees of freedom: 38
# p-value: 0.9515665020676465
# Fail to reject the null hypothesis. There is no significant evidence of a salary gap.

# %% [markdown]
# # Q19 A manufacturer produces two different versions of a product and wants to compare their quality scores. Create a Python function to analyze quality assessment data, calculate the t-statistic, and decide whether there's a significant difference in quality between the two versions.
#
#
# ### Use the following dataY
#
# ### version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
#
# ### version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

# %%
import numpy as np
from scipy.stats import ttest_ind

def compare_product_versions(version1_scores, version2_scores):
  t_stat, p_value = ttest_ind(version1_scores, version2_scores)
  df = len(version1_scores) + len(version2_scores) - 2

  return t_stat, df, p_value

version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

t_stat, df, p_value = compare_product_versions(version1_scores, version2_scores)

print("t-statistic:", t_stat)
print("Degrees of freedom:", df)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
  print("Reject the null hypothesis. There is a significant difference in quality between the two versions.")
else:
  print("Fail to reject the null hypothesis. There is no significant evidence of a quality difference.")
# Out:
# t-statistic: 11.325830417646698
# Degrees of freedom: 48
# p-value: 3.6824250702873965e-15
# Reject the null hypothesis. There is a significant difference in quality between the two versions.

# %% [markdown]
# # Q20. A restaurant chain collects customer satisfaction scores for two different branches. Write a program to analyze the scores, calculate the t-statistic, and determine if there's a statistically significant difference in customer satisfaction between the branches.
#
# ### Use the below data of scores:
#
# ### branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
#
# ### branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

# %%
import numpy as np
from scipy.stats import ttest_ind

def compare_branch_satisfaction(branch_a_scores, branch_b_scores):
    t_stat, p_value = ttest_ind(branch_a_scores, branch_b_scores)
    df = len(branch_a_scores) + len(branch_b_scores) - 2

    return t_stat, df, p_value

branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

t_stat, df, p_value = compare_branch_satisfaction(branch_a_scores, branch_b_scores)

print("t-statistic:", t_stat)
print("Degrees of freedom:", df)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in customer satisfaction between the two branches.")
else:
    print("Fail to reject the null hypothesis. There is no significant evidence of a difference in customer satisfaction.")
# Out:
# t-statistic: 5.480077554195743
# Degrees of freedom: 60
# p-value: 8.895290509945657e-07
# Reject the null hypothesis. There is a significant difference in customer satisfaction between the two branches.

# %% [markdown]
# # Q21. A political analyst wants to determine if there is a significant association between age groups and voter preferences (Candidate A or Candidate B). They collect data from a sample of 500 voters and classify them into different age groups and candidate preferences. Perform a Chi-Square test to determine if there is a significant association between age groups and voter preferences.
#
#
# ### Use the below code to generate data:
#
# ### np.random.seed(0)
#
# ### age_groups = np.random.choice([ 18 30 , 31 50 , 51+', 51+'], size=30)
#
# ### voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30)

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Generate synthetic data
np.random.seed(0)
age_groups = np.random.choice(['18-30', '31-50', '51+'], size=500)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=500)

# Create a DataFrame
data = pd.DataFrame({'Age Group': age_groups, 'Voter Preference': voter_preferences})

# Create a contingency table
contingency_table = pd.crosstab(data['Age Group'], data['Voter Preference'])

# Perform the Chi-Square test
chi2, p_value, _, _ = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant association between age group and voter preference.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between age group and voter preference.")
# Out:
# Chi-Square Statistic: 0.8779923945254768
# p-value: 0.6446832311860852
# Fail to reject the null hypothesis. There is no significant association between age group and voter preference.

# %% [markdown]
# # Q22. A company conducted a customer satisfaction survey to determine if there is a significant relationship between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are located (East, West, North, South). The survey data is summarized in a contingency table. Conduct a Chi-Square test to determine if there is a significant relationship between product satisfaction levels and customer regions.
#
#
# ### Sample data:
#
# ### Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
#
# ### data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Sample data
data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])

# Perform the Chi-Square test
chi2, p_value, _, _ = chi2_contingency(data)

# Print the results
print("Chi-Square Statistic:", chi2)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant association between product satisfaction levels and customer regions.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between product satisfaction levels and customer regions.")
# Out:
# Chi-Square Statistic: 27.777056277056275
# p-value: 0.00010349448486004387
# Reject the null hypothesis. There is a significant association between product satisfaction levels and customer regions.

# %% [markdown]
# # Q23. A company implemented an employee training program to improve job performance (Effective, Neutral, Ineffective). After the training, they collected data from a sample of employees and classified them based on their job performance before and after the training. Perform a Chi-Square test to determine if there is a significant difference between job performance levels before and after the training.
#
# ### Sample data:
#
#
# ### Sample data: Job performance levels before (rows) and after (columns) training
#
# ### data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Sample data
data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])

# Perform the Chi-Square test
chi2, p_value, _, _ = chi2_contingency(data)

# Print the results
print("Chi-Square Statistic:", chi2)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in job performance levels before and after the training.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in job performance levels before and after the training.")
# Out:
# Chi-Square Statistic: 22.161728395061726
# p-value: 0.00018609719479882554
# Reject the null hypothesis. There is a significant difference in job performance levels before and after the training.

# %% [markdown]
# # Q24. A company produces three different versions of a product: Standard, Premium, and Deluxe. The company wants to determine if there is a significant difference in customer satisfaction scores among the three product versions. They conducted a survey and collected customer satisfaction scores for each version from a random sample of customers. Perform an ANOVA test to determine if there is a significant difference in customer satisfaction scores.
#
# ### Use the following data:
#
# ### Sample data: Customer satisfaction scores for each product version
#
# ### standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
#
# ### premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
#
# ### deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

# %%
import numpy as np
from scipy.stats import f_oneway

# Sample data
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(standard_scores, premium_scores, deluxe_scores)

# Print the results
print("F-statistic:", f_statistic)
print("p-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in customer satisfaction scores among the three product versions.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in customer satisfaction scores among the three product versions.")
# Out:
# F-statistic: 27.03556231003039
# p-value: 3.578632885734896e-07
# Reject the null hypothesis. There is a significant difference in customer satisfaction scores among the three product versions.
